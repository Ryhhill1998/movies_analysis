# %%
import os
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
load_dotenv()
movies_csv_file_path = os.getenv("MOVIES_CSV_FILE_PATH")

# %%
movies = pd.read_csv(movies_csv_file_path)
movies.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1137109 entries, 0 to 1137108
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1137109 non-null  int64
#  1   title                 1137096 non-null  object
#  2   vote_average          1137109 non-null  float64
#  3   vote_count            1137109 non-null  int64
#  4   status                1137109 non-null  object
#  5   release_date          949985 non-null   object
#  6   revenue               1137109 non-null  int64
#  7   runtime               1137109 non-null  int64
#  8   adult                 1137109 non-null  bool
#  9   backdrop_path         301743 non-null   object
#  10  budget                1137109 non-null  int64
#  11  homepage              120463 non-null   object
#  12  imdb_id               602754 non-null   object
#  13  original_language     1137109 non-null  object
# ...

# %%
movies.describe()
# Out:
#                  id  vote_average    vote_count       revenue       runtime  \
# count  1.137109e+06  1.137109e+06  1.137109e+06  1.137109e+06  1.137109e+06
# mean   7.408894e+05  1.879332e+00  1.886271e+01  6.917412e+05  4.775990e+01
# std    3.959666e+05  3.021045e+00  3.184448e+02  1.794904e+07  6.167293e+01
# min    2.000000e+00  0.000000e+00  0.000000e+00 -1.200000e+01 -2.800000e+01
# 25%    4.110100e+05  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    7.458520e+05  0.000000e+00  0.000000e+00  0.000000e+00  2.300000e+01
# 75%    1.092447e+06  4.778000e+00  1.000000e+00  0.000000e+00  8.900000e+01
# max    1.392490e+06  1.000000e+01  3.449500e+04  3.000000e+09  1.440000e+04
#
#              budget    popularity
# count  1.137109e+06  1.137109e+06
# mean   2.684443e+05  1.234736e+00
# std    5.074094e+06  7.585587e+00
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  6.000000e-01
# 50%    0.000000e+00  6.000000e-01
# 75%    0.000000e+00  8.770000e-01
# ...

# %%
# TASK 1: Find highest rated movie genre.
# Movies must have at least 100 votes

# %%
def get_top_genres_by_column(movies: pd.DataFrame, column: str, count: int = 5):
    movies_grouped_by_genre = movies.groupby("genre")
    average_column_value = movies_grouped_by_genre[[column]].mean()
    top_genres = average_column_value.nlargest(count, columns=[column])
    return top_genres

# %%
def plot_bar_chart(x, height, title: str, xlabel: str, ylabel: str):
    fig, ax = plt.subplots()
    
    ax.bar(x=x, height=height)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_ylim(bottom=height.min() * 0.95, top=height.max() * 1.025)
    
    plt.xticks(rotation=90)
    plt.show()

# %%
# Genres are comma-separated strings - splitting so that each movie appears once for each of its genres
movies_by_genre = movies.copy()
movies_by_genre["genres"] = movies_by_genre["genres"].str.split(", ")
movies_by_genre = movies_by_genre.explode("genres").rename(columns={"genres": "genre"}).reset_index(drop=True)
movies_by_genre = movies_by_genre.drop_duplicates(subset=["id", "genre"])

# %%
movies_with_min_votes = movies_by_genre[movies_by_genre["vote_count"] >= 100]
top_genres_by_vote_average = get_top_genres_by_column(movies=movies_with_min_votes, column="vote_average", count=5)
top_genres_by_vote_average
# Out:
#              vote_average
# genre
# Documentary      7.251404
# Animation        7.002661
# History          6.980965
# War              6.960715
# Music            6.905070

# %%
plot_bar_chart(
    x=top_genres_by_vote_average.index, 
    height=top_genres_by_vote_average["vote_average"], 
    title="Top 5 Genres by Movie Rating", 
    xlabel="Genre", 
    ylabel="Average movie rating"
)

# %%
top_genres_by_revenue = get_top_genres_by_column(movies=movies_by_genre, column="revenue", count=5)
top_genres_by_revenue
# Out:
#                       revenue
# genre
# Adventure        1.276943e+07
# Action           6.874577e+06
# Science Fiction  6.864573e+06
# Fantasy          6.551373e+06
# Family           4.932602e+06

# %%
plot_bar_chart(
    x=top_genres_by_revenue.index, 
    height=top_genres_by_revenue["revenue"], 
    title="Top 5 Genres by Movie Revenue", 
    xlabel="Genre", 
    ylabel="Average movie revenue"
)

# %%
top_genres_by_budget = get_top_genres_by_column(movies=movies_by_genre, column="budget", count=5)
top_genres_by_budget
# Out:
#                        budget
# genre
# Adventure        4.344678e+06
# Action           2.672359e+06
# Science Fiction  2.663174e+06
# Fantasy          2.302511e+06
# Family           1.738534e+06

# %%
plot_bar_chart(
    x=top_genres_by_budget.index, 
    height=top_genres_by_budget["budget"], 
    title="Top 5 Genres by Movie Budget", 
    xlabel="Genre", 
    ylabel="Average movie budget"
)

# %%
top_genres_by_runtime = get_top_genres_by_column(movies=movies_by_genre, column="budget", count=5)
top_genres_by_budget
